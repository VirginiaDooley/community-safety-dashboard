# %%
import pandas as pd
import glob

all_files = glob.glob("data/uk/2024-*-metropolitan-street.csv")
all_data = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

all_data_df = pd.DataFrame(all_data)

all_data_df = all_data_df.dropna(subset=['LSOA name'])

k_and_c_data = all_data_df[all_data_df['LSOA name'].str.contains("Kensington and Chelsea")]

months = ['2024-01', '2024-02', '2024-03', '2024-04', '2024-05', '2024-06', '2024-07', '2024-08', '2024-09']
monthly_data = {month: k_and_c_data[k_and_c_data['Month'] == month] for month in months}

# %% [markdown]
# # 2024 crime by type in Kensington and Chelsea

# %%
import matplotlib.pyplot as plt

plt.title('Crimes by type in Kensington and Chelsea')
plt.xlabel('Crime type')
plt.ylabel('Number of crimes')
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'orange', 'purple']
for month, data, color in zip(monthly_data.keys(), monthly_data.values(), colors):
	data['Crime type'].value_counts().plot(kind='bar', color=color, label=month)
plt.legend()
plt.show()

# %% [markdown]
# # Where do violent and sexual crimes happen in Kensington and Chelsea?

# %%
df = df[df['LSOA name'].str.contains("Kensington and Chelsea")]	
df = df[df['Crime type'].str.contains("Violence and sexual offences")]
# TODO: make this into an interactive map using longitude and latitude and location data
