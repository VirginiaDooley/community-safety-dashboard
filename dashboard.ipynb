# %%
import pandas as pd

data = pd.read_csv("data/uk/2024-09/2024-09-metropolitan-street.csv")

df = pd.DataFrame(data)

ken_and_chelsea = df[df['LSOA name'].str.contains("Kensington and Chelsea")]

# %% [markdown]
# # Crime by type in Kensington and Chelsea

# %%
import matplotlib.pyplot as plt

ken_and_chelsea['Crime type'].value_counts().plot(kind='bar')
plt.title('Crimes by type in Kensington and Chelsea for September 2024')
plt.xlabel('Crime type')
plt.ylabel('Number of crimes')
plt.show()

# %% [markdown]
# # Where do violent and sexual crimes happen in Kensington and Chelsea?

# %%
df = df[df['LSOA name'].str.contains("Kensington and Chelsea")]	
df = df[df['Crime type'].str.contains("Violence and sexual offences")]
# TODO: make this into an interactive map using longitude and latitude and location data
